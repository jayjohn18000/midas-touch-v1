# %%
import sys
sys.path.append("visualization")

from plotter import plot_summary_bar, plot_equity_curve, plot_top_n_equity_curves

plot_summary_bar(save=True)
plot_top_n_equity_curves(n=5, save=True)
plot_equity_curve("results/equity_curves/SOL-ETH.csv", save=True)
# Out:
# 📸 Saved plot to figures/summary_Percent_Return.png
# 📸 Saved plot to figures/top_5_equity_curves_sma_crossover.png
# 📸 Saved plot to figures/equity_curve_SOL-ETH.png

# %%
plot_summary_bar()  # or plot_summary_bar(metric="Final Equity")

# %%
plot_top_n_equity_curves(n=5)

# %%
plot_equity_curve("results/equity_curves/BTC-USD.csv")
plot_equity_curve("results/equity_curves/ETH-USD.csv")
